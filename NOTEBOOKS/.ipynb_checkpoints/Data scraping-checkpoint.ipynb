# %%
import requests

from bs4 import BeautifulSoup as bs
import pandas as pd
from tqdm import tqdm_notebook

# %%
res = requests.get("https://en.wiktionary.org/wiki/Category:Swadesh_lists_by_language")
soup = bs(res.text, "html.parser")
swadesh_lists = []
for link in soup.find_all("a", href=True):
    url = link["href"]
    if "Appendix" in url:
        swadesh_lists.append('https://en.wiktionary.org' + url)

# %%
DF = pd.DataFrame()
all_df = {}

# %%
cols = set()
for url in tqdm_notebook(swadesh_lists):
    if url != 'https://en.wiktionary.org/wiki/Appendix:Swadesh_lists' and url != 'https://en.wiktionary.org/wiki/Appendix:Glossary':
        table = pd.read_html(url)
        df = table[0]
        colset = set(df.columns)
        cols = cols.union(colset)
# Out:
# HBox(children=(IntProgress(value=0, max=201), HTML(value='')))
# {'English', 'Afrikaansedit (207)', 'IPA', '№'}
# set()
# {'Aikanã', 'Notes', 'English gloss', 'No.'}
# set()
# {'Albanianshqipedit (207)', 'English', 'IPA', '№'}
# set()
# {'English', 'IPA', 'Amharicአማርኛedit (207)', '№'}
# set()
# {'English', 'Ancient Greekἑλληνική (hellēnikḗ)', 'No.'}
# set()
# {'no.', 'English gloss', 'Andoque', 'Spanish gloss'}
# set()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-86fea1cdd5f9> in <module>
#       2 for url in tqdm_notebook(swadesh_lists):
#       3     if url != 'https://en.wiktionary.org/wiki/Appendix:Swadesh_lists' and url != 'https://en.wiktionary.org/wiki/Appendix:Glossary':
# ----> 4         table = pd.read_html(url)
#       5         df = table[0]
#       6         print(set(df.columns))
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1092                   decimal=decimal, converters=converters, na_values=na_values,
#    1093                   keep_default_na=keep_default_na,
# -> 1094                   displayed_only=displayed_only)
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     896
#     897         try:
# --> 898             tables = p.parse_tables()
#     899         except Exception as caught:
#     900             # if `io` is an io-like object, check if it's seekable
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in parse_tables(self)
#     219         list of parsed (header, body, footer) tuples from tables.
#     220         """
# --> 221         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     222         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     223
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in _build_doc(self)
#     717             if _is_url(self.io):
#     718                 with urlopen(self.io) as f:
# --> 719                     r = parse(f, parser=parser)
#     720             else:
#     721                 # try to parse the input in the simplest way
#
# ~\Anaconda3\lib\site-packages\lxml\html\__init__.py in parse(filename_or_url, parser, base_url, **kw)
#     937     if parser is None:
#     938         parser = html_parser
# --> 939     return etree.parse(filename_or_url, parser, base_url=base_url, **kw)
#     940
#     941
#
# src/lxml/etree.pyx in lxml.etree.parse()
#
# src/lxml/parser.pxi in lxml.etree._parseDocument()
#
# src/lxml/parser.pxi in lxml.etree._parseFilelikeDocument()
#
# src/lxml/parser.pxi in lxml.etree._parseDocFromFilelike()
#
# src/lxml/parser.pxi in lxml.etree._BaseParser._parseDocFromFilelike()
#
# src/lxml/parser.pxi in lxml.etree._ParserContext._handleParseResultDoc()
#
# src/lxml/parser.pxi in lxml.etree._handleParseResult()
#
# src/lxml/etree.pyx in lxml.etree._ExceptionContext._raise_if_stored()
#
# src/lxml/parser.pxi in lxml.etree._FileReaderContext.copyToBuffer()
#
# ~\Anaconda3\lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# ~\Anaconda3\lib\http\client.py in readinto(self, b)
#     491         # connection, and the user is reading more bytes than will be provided
#     492         # (for example, reading in 1k chunks)
# --> 493         n = self.fp.readinto(b)
#     494         if not n and b:
#     495             # Ideally, we would raise IncompleteRead if the content-length
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
{1,2} union {3,4}
# Out:
#   File "<ipython-input-41-2809bddec1b8>", line 1
#     {1,2} union {3,4}
#               ^
# SyntaxError: invalid syntax

# %%
for url in tqdm_notebook(swadesh_lists):
    if url != 'https://en.wiktionary.org/wiki/Appendix:Swadesh_lists' and url != 'https://en.wiktionary.org/wiki/Appendix:Glossary':
        table = pd.read_html(url)
        df = table[0]
        trivial_columns = ['No.', '№',  ]
        try:
            df.drop('№', inplace=True)
        all_df[swadesh_lists[n][40:]] = df
# Out:
# HBox(children=(IntProgress(value=0, max=190), HTML(value='')))

# %%
len(all_df.keys())
# Out:
# 188

# %%
list(all_df.keys())[52]
# Out:
# 'Hausa_Swadesh_list'

# %%
all_df['Hausa_Swadesh_list']
# Out:
#      No.             English                        Hausahausa
# 0      1                   I                                ni
# 1      2      you (singular)                               kai
# 2      3                  he                               shi
# 3      4                  we                                mu
# 4      5        you (plural)                                ku
# 5      6                they                                su
# 6      7                this                            wannan
# 7      8                that                            wancan
# 8      9                here                               NaN
# 9     10               there                               can
# 10    11                 who                wa (interrogative)
# 11    12                what                me (interrogative)
# 12    13               where  ina (no movement, interrogative)
# 13    14                when            yaushe (interrogative)
# 14    15                 how              yaya (interrogative)
# 15    16                 not                            ba ...
# 16    17                 all                               duk
# 17    18                many                           da yawa
# 18    19                some                           waɗansu
# 19    20                 few                             kaɗan
# 20    21               other                            wancan
# 21    22                 one                              ɗaya
# 22    23                 two                              biyu
# 23    24               three                               uku
# 24    25                four                              huɗu
# 25    26                five                             biyar
# 26    27                 big                             babba
# 27    28                long                              dogo
# 28    29                wide                          mai faɗi
# 29    30               thick                         mai kauri
# ..   ...                 ...                               ...
# 177  178                 day                        rana, yini
# 178  179                year                           shekara
# 179  180                warm                          mai ɗumi
# 180  181                cold                         mai sanyi
# 181  182                full                           cikakke
# 182  183                 new                              sabo
# 183  184                 old                             tsoho
# 184  185                good                          mai kyau
# 185  186                 bad                        maras kyau
# 186  187              rotten                           ruɓaɓɓe
# 187  188               dirty                         mai dauɗa
# 188  189            straight                           miƙaƙƙe
# 189  190               round                        mai da’ira
# 190  191  sharp (as a knife)                         mai kaifi
# 191  192   dull (as a knife)                       maras kaifi
# 192  193              smooth                        mai santsi
# 193  194                 wet                           jiƙaƙƙe
# 194  195                 dry                       maras laima
# 195  196             correct                        madaidaici
# 196  197                near                           kusa da
# 197  198                 far                          mai nisa
# 198  199               right                              dama
# 199  200                left                              hagu
# 200  201                  at                          a, wurin
# 201  202                  in                          a, cikin
# 202  203                with                                da
# 203  204                 and                          da, kuma
# 204  205                  if                          in, idan
# 205  206             because                               don
# 206  207                name                              suna
#
# [207 rows x 3 columns]
